# %% [markdown]
# # Dataset Inspection
#
# Notebook ini dipakai untuk mengecek struktur dataset sebelum training.

# %%
from pathlib import Path

from src.data.inspector import inspect_dataset

DATA_DIR = "../data"
summary = inspect_dataset(DATA_DIR)
print(summary)
